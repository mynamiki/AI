# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# %% [markdown]
# # Dados Educacao de Pessoas Alfabetizadas

# %%
dados_educacao_nao_alfabetizados_2005_df = pd.read_csv('dados_educacao-nao-alfabetizadas-2005.csv', sep=';')
dados_educacao_nao_alfabetizados_2005_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   4937    2581      2355       3792        1973
# 1            7 anos    965     527       438        639         355
# 2        8 e 9 anos    902     524       378        499         292
# 3      10 a 14 anos    579     404       175        314         219
# 4      15 a 19 anos    407     285       123        228         154
# 5      20 a 24 anos    595     389       205        328         208
# 6      25 a 29 anos    886     544       342        489         293
# 7      30 a 39 anos   2089    1199       890       1209         673
# 8      40 a 49 anos   2518    1309      1209       1551         753
# 9      50 a 59 anos   2833    1311      1522       1776         754
# 10  60 anos ou mais   5658    2302      3356       3987        1473
# 11   Idade ignorada      9       5         4          8           4
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# ...

# %%
dados_educacao_nao_alfabetizados_2005_df = dados_educacao_nao_alfabetizados_2005_df[:-1] #drop lastline 
dados_educacao_nao_alfabetizados_2005_df
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0        5 e 6 anos   4937    2581      2355       3792        1973
# 1            7 anos    965     527       438        639         355
# 2        8 e 9 anos    902     524       378        499         292
# 3      10 a 14 anos    579     404       175        314         219
# 4      15 a 19 anos    407     285       123        228         154
# 5      20 a 24 anos    595     389       205        328         208
# 6      25 a 29 anos    886     544       342        489         293
# 7      30 a 39 anos   2089    1199       890       1209         673
# 8      40 a 49 anos   2518    1309      1209       1551         753
# 9      50 a 59 anos   2833    1311      1522       1776         754
# 10  60 anos ou mais   5658    2302      3356       3987        1473
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           1819       1144         608           536
# ...

# %%
dados_educacao_nao_alfabetizados_2015_df = pd.read_csv('dados_educacao-nao-alfabetizadas-2015.csv', sep=';')
dados_educacao_nao_alfabetizados_2015_df.head(100)
# Out:
#             Classes  Total  Homens  Mulheres  Total_URB  Homens_URB  \
# 0       5 ou 6 anos   3308    1694      1615       2641        1349
# 1            7 anos    562     308       254        387         206
# 2       8 ou 9 anos    431     257       174        262         163
# 3      10 a 14 anos    250     164        86        166         109
# 4      15 a 19 anos    142      97        46         92          63
# 5      20 a 24 anos    200     140        60        125          83
# 6      25 a 29 anos    296     185       112        170         100
# 7      30 a 39 anos   1274     790       484        692         401
# 8      40 a 49 anos   1975    1151       824       1130         625
# 9      50 a 59 anos   2422    1223      1199       1479         697
# 10  60 anos ou mais   6556    2818      3738       4488        1728
#
#     Mulheres_URB  Total_RUR  Homens_RUR  Mulheres_RUR
# 0           1292        667         345           322
# ...

# %% [markdown]
# ## Análise da distribuição das classes

# %% [markdown]
# ### 2005 vs 2015

# %%
cols = ['Homens', 'Mulheres']
desc_cols = ['Homens', 'Mulheres']
years = [2005, 2015]
dfs = [dados_educacao_nao_alfabetizados_2005_df, dados_educacao_nao_alfabetizados_2015_df]

num_cols = 2
fig, ax = plt.subplots(nrows=1, ncols=num_cols, figsize=(20, num_cols*5))

for index, col in enumerate(dfs):
   
    height1 = dfs[index][cols[0]]
    height2 = dfs[index][cols[1]]

    bars = dados_educacao_nao_alfabetizados_2005_df['Classes']
    y_pos = np.arange(len(bars))
    plt.figure(figsize=(20, 7))
    
    p1 = ax[index].barh(y_pos, height1, alpha = 0.8, color = 'b')
    p2 = ax[index].barh(y_pos, height2, alpha = 0.3, color = 'r')
    
    ax[index].title.set_text(f"Não Alfabetizados em ({years[index]})")
    ax[index].set_yticks(y_pos)
    ax[index].set_yticklabels(bars)
    ax[index].set_xlabel('População impactada (1000)')
    ax[index].legend((p1[0], p2[0]), desc_cols)

# %% [markdown]
# #### Conclusão: houve redução no número de analfabetos em todas as faixas, principalmente entre as crianças e os jovens.
